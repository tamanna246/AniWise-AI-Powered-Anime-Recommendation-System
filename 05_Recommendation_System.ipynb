# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

from scipy.sparse import csr_matrix, hstack

# %%
df = pd.read_csv("../data/processed/anime_cleaned.csv")

# %%
df["search_title"] = (
    df["title"]
    .fillna("")
    .str.lower()
)

# %%
metadata_columns = [
    "genres",
    "themes",
    "studios",
    "demographics"
]

for col in metadata_columns:
    df[col] = (
        df[col]
        .fillna("")
        .str.lower()
    )

df["synopsis_text"] = (
    df["synopsis"]
    .fillna("")
    .str.lower()
)

# %%
REMOVE_THEMES = {

    "award winning",

    "adult cast"

}

# %%
for col in metadata_columns:

    df[col] = df[col].apply(

        lambda x: [

            i.strip()

            for i in x.split(",")

            if i.strip() != ""

        ]

    )

# %%
def clean_theme_list(theme_list):

    return [

        x

        for x in theme_list

        if x not in REMOVE_THEMES

    ]

df["themes"] = df["themes"].apply(clean_theme_list)

# %%
df["themes"].head()
# Out:
# 0        [space]
# 1        [space]
# 2             []
# 3    [detective]
# 4      [unknown]
# Name: themes, dtype: object

# %%
genre_encoder = MultiLabelBinarizer()
theme_encoder = MultiLabelBinarizer()
studio_encoder = MultiLabelBinarizer()
demo_encoder = MultiLabelBinarizer()

genre_matrix = genre_encoder.fit_transform(df["genres"])
theme_matrix = theme_encoder.fit_transform(df["themes"])
studio_matrix = studio_encoder.fit_transform(df["studios"])
demo_matrix = demo_encoder.fit_transform(df["demographics"])

# %%
genre_sparse = csr_matrix(genre_matrix)
theme_sparse = csr_matrix(theme_matrix)
studio_sparse = csr_matrix(studio_matrix)
demo_sparse = csr_matrix(demo_matrix)

# %%
synopsis_vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=12000,
    min_df=5
)

synopsis_matrix = synopsis_vectorizer.fit_transform(
    df["synopsis_text"]
)

# %%
from scipy.sparse import hstack

final_matrix = hstack([

    genre_sparse * 4,

    theme_sparse * 3,

    demo_sparse * 2,

    studio_sparse * 0.3,

    synopsis_matrix * 2

])

# %%
print(final_matrix.shape)
# Out:
# (28491, 13342)

# %%
knn_model = NearestNeighbors(
    metric="cosine",
    algorithm="brute",
    n_neighbors=50
)

knn_model.fit(final_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=50)

# %%
english_alias = {

    "attack on titan": "shingeki no kyojin",
    "aot": "shingeki no kyojin",

    "demon slayer": "kimetsu no yaiba",

    "jjk": "jujutsu kaisen",

    "my hero academia": "boku no hero academia",

    "fmab": "fullmetal alchemist: brotherhood",

    "konosuba": "kono subarashii sekai ni shukufuku wo!",

    "oshi no ko": "oshi no ko",

    "spy x family": "spy x family",

    "one punch man": "one punch man",

    "tokyo ghoul": "tokyo ghoul",

    "bleach": "bleach",

    "naruto shippuden": "naruto: shippuuden",

    "dragon ball super": "dragon ball super",

    "steins gate": "steins;gate",

    "code geass": "code geass: hangyaku no lelouch"

}

# %%
import pandas as pd

def recommend_anime(anime_name, top_n=10):

    anime_name = anime_name.lower().strip()
    anime_name = english_alias.get(
        anime_name,
        anime_name
    )

    # -------------------------
    # Search Anime
    # -------------------------
    matches = df[
    df["search_title"].str.contains(
        anime_name.lower(),
        na=False
    )
]

    if matches.empty:
        print("❌ Anime not found.")
        return

# Prefer exact match
    exact = matches[
    matches["search_title"] == anime_name.lower()
]

    if not exact.empty:
        selected_index = exact.index[0]
    else:
        selected_index = matches.index[0]
    
    selected_title = df.loc[selected_index, "title"]

    print(f"\n🎯 Recommendations for '{selected_title}'\n")

    # -------------------------
    # KNN Search
    # -------------------------
    distances, indices = knn_model.kneighbors(
        final_matrix[selected_index],
        n_neighbors=50
    )

    recommendations = []
    used_titles = set()

    # Franchise name
    franchise = (
        selected_title
        .split(":")[0]
        .split("-")[0]
        .lower()
        .strip()
    )

    for distance, idx in zip(distances[0], indices[0]):

        if idx == selected_index:
            continue

        anime = df.iloc[idx]
        title = anime["title"].strip()

        # title = anime["title"]

        # --------------------------------
        # Remove Franchise Sequels
        # --------------------------------

        title_lower = title.lower()

        if title_lower.startswith(franchise):
            continue

        # --------------------------------
        # Skip duplicate titles
        # --------------------------------

        if title in used_titles:
            continue

        # --------------------------------
        # Skip PV / Music / Commercial
        # --------------------------------

        if anime["type"].upper() in ["PV", "CM", "MUSIC"]:
            continue

        # --------------------------------
        # Score Filter
        # --------------------------------

        score = anime["score"]

        if pd.notna(score):

            if score < 6.5:
                continue

        similarity = round((1-distance)*100,2)

        recommendations.append({

            "Title":title,

            "Similarity (%)":similarity,

            "Genres": ", ".join(anime["genres"]).title(),

            "Studio": ", ".join(anime["studios"]).title(),

            "Type":anime["type"].upper(),

            "Score":round(score,2) if pd.notna(score) else "N/A",

            "URL":anime["url"]

        })

        used_titles.add(title)

        if len(recommendations)==top_n:
            break

    result = pd.DataFrame(recommendations)

    result = result.sort_values(
        by=["Similarity (%)", "Score"],
        ascending=False
    )

    return result.reset_index(drop=True)
    # return pd.DataFrame(recommendations)

# %%
recommend_anime("Death Note")
# Out:
# 🎯 Recommendations for 'Death Note'
#                                                Title  Similarity (%)  \
# 0                                Mirai Nikki: Redial           91.95
# 1                                        Shinreigari           73.15
# 2                                Wonder Egg Priority           72.77
# 3  Monogatari Series: Off & Monster Season - Zank...           67.98
# 4                                   Mirai Nikki (TV)           67.13
# 5                           Jigoku Shoujo Futakomori           65.17
# 6                                            Kokkoku           65.15
# 7                                      Jigoku Shoujo           65.14
# 8                           Jigoku Shoujo Mitsuganae           65.02
# 9                               Cong Hong Yue Kaishi           65.02
#
#                                     Genres          Studio Type  Score  \
# 0                   Supernatural, Suspense         Asread.  OVA   7.28
# 1          Mystery, Supernatural, Suspense  Production I.G   TV   7.39
# 2            Drama, Supernatural, Suspense     Cloverworks   TV   7.55
# 3          Mystery, Supernatural, Suspense           Shaft  ONA   7.73
# 4           Action, Supernatural, Suspense         Asread.   TV   7.38
# 5  Horror, Mystery, Supernatural, Suspense     Studio Deen   TV   7.87
# 6   Drama, Mystery, Supernatural, Suspense     Geno Studio   TV   6.98
#                                 Genres        Studio        Type  Score  \
# 0  Action, Award Winning, Supernatural         Mappa          TV   8.55
# 1                 Action, Supernatural     Doga Kobo          TV   7.46
# 2                 Action, Supernatural    Wit Studio       MOVIE   7.40
# 3                 Action, Supernatural    Wit Studio       MOVIE   7.21
# 4                 Action, Supernatural    P.A. Works          TV   6.95
# 5                 Action, Supernatural   Studio Deen          TV   7.53
# 6                 Action, Supernatural    Wit Studio       MOVIE   7.51
# 7                 Action, Supernatural   Studio Deen  TV SPECIAL   6.68
# 8        Action, Romance, Supernatural         Gonzo          TV   7.60
# 9         Action, Comedy, Supernatural  A-1 Pictures          TV   7.12
#
#                                                  URL
# 0  https://myanimelist.net/anime/40748/Jujutsu_Ka...
# 1  https://myanimelist.net/anime/21743/Donten_ni_...
# 2  https://myanimelist.net/anime/35086/Donten_ni_...
# 3  https://myanimelist.net/anime/35425/Donten_ni_...
# 4         https://myanimelist.net/anime/37569/Sirius
# 5  https://myanimelist.net/anime/1557/Shounen_Onm...
# 6  https://myanimelist.net/anime/35424/Donten_ni_...
# 7  https://myanimelist.net/anime/11083/Nurarihyon...
# 8     https://myanimelist.net/anime/60/Chrno_Crusade
# 9  https://myanimelist.net/anime/6707/Kuroshitsuj...

# %%
recommend_anime("Code Geass")
# Out:
# 🎯 Recommendations for 'Code Geass: Hangyaku no Lelouch'
#                                             Title  Similarity (%)  \
# 0     Shin Kidou Senki Gundam Wing: Endless Waltz           83.25
# 1  Soukyuu no Fafner: Dead Aggressor - The Beyond           80.37
# 2                                    Guilty Crown           78.62
# 3                          Taiyou no Kiba Dougram           78.47
# 4                                       86 Part 2           78.44
# 5                                              86           78.39
# 6                 Soukou Kihei Votoms: Big Battle           78.39
# 7          Kidou Senshi Gundam 00 Special Edition           78.32
# 8      Soukou Kihei Votoms: The Last Red Shoulder           78.32
# 9         Kidou Senshi Gundam AGE: Memory of Eden           78.32
#
#                                  Genres                   Studio   Type  \
# 0  Action, Award Winning, Drama, Sci-Fi                  Sunrise    OVA
# 1                 Action, Drama, Sci-Fi  Production I.G, I.Gzwei  MOVIE
# 2                 Action, Drama, Sci-Fi           Production I.G     TV
# 3                 Action, Drama, Sci-Fi                  Sunrise     TV
# 4                 Action, Drama, Sci-Fi             A-1 Pictures     TV
# 5                 Action, Drama, Sci-Fi             A-1 Pictures     TV
# 6                 Action, Drama, Sci-Fi                  Sunrise    OVA
# 7                 Action, Drama, Sci-Fi                  Sunrise    OVA
# 8                 Action, Drama, Sci-Fi                  Sunrise    OVA
# 9                 Action, Drama, Sci-Fi                  Sunrise    OVA
#
#    Score                                                URL
# 0   7.73  https://myanimelist.net/anime/91/Shin_Kidou_Se...
# 1   7.27  https://myanimelist.net/anime/34649/Soukyuu_no...
# 2   7.40   https://myanimelist.net/anime/10793/Guilty_Crown
# 3   7.40  https://myanimelist.net/anime/2257/Taiyou_no_K...
# 4   8.72      https://myanimelist.net/anime/48569/86_Part_2
# 5   8.33             https://myanimelist.net/anime/41457/86
# 6   6.71  https://myanimelist.net/anime/2584/Soukou_Kihe...
# 7   7.53  https://myanimelist.net/anime/7270/Kidou_Sensh...
# 8   7.11  https://myanimelist.net/anime/2583/Soukou_Kihe...
# 9   6.62  https://myanimelist.net/anime/17655/Kidou_Sens...

# %%
recommend_anime("Naruto")
# Out:
# 🎯 Recommendations for 'Naruto'
#                                     Title  Similarity (%)  \
# 0  Boruto: Naruto Next Generations Part 2           96.74
# 1                Boruto: Naruto the Movie           95.84
# 2    Dragon Ball Z Movie 14: Kami to Kami           93.79
# 3           Dragon Ball Super: Super Hero           93.77
# 4                Dragon Ball Super: Broly           93.75
# 5                Juushin Enbu: Hero Tales           93.72
# 6                Ba Jie: Tian Peng Xiajie           90.39
# 7                               Son Ogong           90.39
# 8                        Xian Ji Xun Zong           90.39
# 9                     Xin Xiyou Lixian Ji           90.39
#
#                        Genres            Studio   Type Score  \
# 0  Action, Adventure, Fantasy           Unknown     TV   N/A
# 1  Action, Adventure, Fantasy           Pierrot  MOVIE  7.38
# 2  Action, Adventure, Fantasy    Toei Animation  MOVIE  7.41
# 3  Action, Adventure, Fantasy    Toei Animation  MOVIE  7.58
# 4  Action, Adventure, Fantasy    Toei Animation  MOVIE  8.19
# 5  Action, Adventure, Fantasy       Studio Flag     TV  6.81
# 6  Action, Adventure, Fantasy           Unknown  MOVIE   N/A
# 7  Action, Adventure, Fantasy           Unknown  MOVIE   N/A
# 8  Action, Adventure, Fantasy  Ruo Hong Culture    ONA   N/A
# 9  Action, Adventure, Fantasy           Unknown     TV   N/A
#
#                                                  URL
# 0  https://myanimelist.net/anime/54687/Boruto__Na...
# 1  https://myanimelist.net/anime/28755/Boruto__Na...
# 2  https://myanimelist.net/anime/14837/Dragon_Bal...
# 3  https://myanimelist.net/anime/48903/Dragon_Bal...
# 4  https://myanimelist.net/anime/36946/Dragon_Bal...
# 5  https://myanimelist.net/anime/2772/Juushin_Enb...
# 6  https://myanimelist.net/anime/57931/Ba_Jie__Ti...
# 7      https://myanimelist.net/anime/42292/Son_Ogong
# 8  https://myanimelist.net/anime/60066/Xian_Ji_Xu...
# 9  https://myanimelist.net/anime/58557/Xin_Xiyou_...

# %%
import joblib
from scipy.sparse import save_npz

# Save KNN model
joblib.dump(knn_model, "knn_model.pkl")

# Save feature matrix
save_npz("final_matrix.npz", final_matrix)

# Save processed dataset
df.to_csv("anime.csv", index=False)

print("✅ Everything saved successfully!")
# Out:
# ✅ Everything saved successfully!

# %%
print(df["search_title"].head(10))
# Out:
# 0                       cowboy bebop
# 1    cowboy bebop: tengoku no tobira
# 2                             trigun
# 3                 witch hunter robin
# 4                     bouken ou beet
# 5                       eyeshield 21
# 6               hachimitsu to clover
# 7         hungry heart: wild striker
# 8             initial d fourth stage
# 9                            monster
# Name: search_title, dtype: str
