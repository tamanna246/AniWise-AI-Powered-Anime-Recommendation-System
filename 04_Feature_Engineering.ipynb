# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 200)

# %%
df = pd.read_csv("../data/processed/anime_cleaned.csv")

# %%
features_df = df[
    [
        "mal_id",
        "title",
        "title_english",
        "genres",
        "themes",
        "studios",
        "demographics",
        "type",
        "synopsis",
        "url"
    ]
].copy()

# %%
features_df.head()
# Out:
#    mal_id                            title            title_english  \
# 0       1                     Cowboy Bebop             Cowboy Bebop
# 1       5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2       6                           Trigun                   Trigun
# 3       7               Witch Hunter Robin       Witch Hunter Robin
# 4       8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                                  genres             themes         studios  \
# 0         Action, Award Winning, Sci-Fi  Adult Cast, Space         Sunrise
# 1                        Action, Sci-Fi  Adult Cast, Space           Bones
# 2             Action, Adventure, Sci-Fi         Adult Cast        Madhouse
# 3  Action, Drama, Mystery, Supernatural          Detective         Sunrise
# 4            Action, Adventure, Fantasy            Unknown  Toei Animation
#
#   demographics   type  \
# 0      Unknown     TV
# 1      Unknown  Movie
# 2      Shounen     TV
# 3      Unknown     TV
# 4      Shounen     TV
#
#                                                                                                                                                                                                   synopsis  \
# 0  Crime is timeless. By the year 2071, humanity has expanded across the galaxy, filling the surface of other planets with settlements like those on Earth. These new societies are plagued by murder, ...
# 1  Another day, another bounty—such is the life of the often unlucky crew of the Bebop. However, this routine is interrupted when Faye, who is chasing a fairly worthless target on Mars, witnesses an ...
# 2  Vash the Stampede is the man with a $$60,000,000,000 bounty on his head. The reason: he's a merciless villain who lays waste to all those that oppose him and flattens entire cities for fun, garner...
# 3  Though hidden away from the general public, Witches—those with supernatural powers—have always existed in human societies. Neither numerous nor inherently evil, Witches are nonetheless capable of ...
# 4  It is the dark century and the people are suffering under the rule of the devil, Vandel, who is able to manipulate monsters. The Vandel Busters are a group of people who hunt these devils, and amo...
#
#                                                                url
# 0                     https://myanimelist.net/anime/1/Cowboy_Bebop
# 1  https://myanimelist.net/anime/5/Cowboy_Bebop__Tengoku_no_Tobira
# 2                           https://myanimelist.net/anime/6/Trigun
# 3               https://myanimelist.net/anime/7/Witch_Hunter_Robin
# 4                   https://myanimelist.net/anime/8/Bouken_Ou_Beet

# %%
features_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28491 entries, 0 to 28490
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mal_id         28491 non-null  int64
#  1   title          28491 non-null  str
#  2   title_english  12232 non-null  str
#  3   genres         28491 non-null  str
#  4   themes         28491 non-null  str
#  5   studios        28491 non-null  str
#  6   demographics   28491 non-null  str
#  7   type           28491 non-null  str
#  8   synopsis       23443 non-null  str
#  9   url            28491 non-null  str
# dtypes: int64(1), str(9)
# memory usage: 14.5 MB

# %%
text_columns = [
    "genres",
    "themes",
    "studios",
    "demographics",
    "type"
]


for col in text_columns:
    features_df[col] = (
        features_df[col]
        .str.lower()
        .str.replace(",", " ", regex=False)
        .str.replace(" ", "_", regex=False)
    )

# %%
features_df["synopsis"] = (
    features_df["synopsis"]
    .fillna("")
    .str.lower()
)

# %%
features_df.head()
# Out:
#    mal_id                            title            title_english  \
# 0       1                     Cowboy Bebop             Cowboy Bebop
# 1       5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2       6                           Trigun                   Trigun
# 3       7               Witch Hunter Robin       Witch Hunter Robin
# 4       8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                                  genres             themes         studios  \
# 0         action__award_winning__sci-fi  adult_cast__space         sunrise
# 1                        action__sci-fi  adult_cast__space           bones
# 2             action__adventure__sci-fi         adult_cast        madhouse
# 3  action__drama__mystery__supernatural          detective         sunrise
# 4            action__adventure__fantasy            unknown  toei_animation
#
#   demographics   type  \
# 0      unknown     tv
# 1      unknown  movie
# 2      shounen     tv
# 3      unknown     tv
# 4      shounen     tv
#
#                                                                                                                                                                                                   synopsis  \
# 0  crime is timeless. by the year 2071, humanity has expanded across the galaxy, filling the surface of other planets with settlements like those on earth. these new societies are plagued by murder, ...
# 1  another day, another bounty—such is the life of the often unlucky crew of the bebop. however, this routine is interrupted when faye, who is chasing a fairly worthless target on mars, witnesses an ...
# 2  vash the stampede is the man with a $$60,000,000,000 bounty on his head. the reason: he's a merciless villain who lays waste to all those that oppose him and flattens entire cities for fun, garner...
# 3  though hidden away from the general public, witches—those with supernatural powers—have always existed in human societies. neither numerous nor inherently evil, witches are nonetheless capable of ...
# 4  it is the dark century and the people are suffering under the rule of the devil, vandel, who is able to manipulate monsters. the vandel busters are a group of people who hunt these devils, and amo...
#
#                                                                url
# 0                     https://myanimelist.net/anime/1/Cowboy_Bebop
# 1  https://myanimelist.net/anime/5/Cowboy_Bebop__Tengoku_no_Tobira
# 2                           https://myanimelist.net/anime/6/Trigun
# 3               https://myanimelist.net/anime/7/Witch_Hunter_Robin
# 4                   https://myanimelist.net/anime/8/Bouken_Ou_Beet

# %%
boilerplate = (
    "No synopsis has been added for this series yet.\n\n"
    "Click here to update this information."
)

features_df["synopsis"] = (
    features_df["synopsis"].replace(boilerplate, "")
)

# %%
features_df["combined_features"] = (
    features_df["genres"] + " " +
    features_df["themes"] + " " +
    features_df["studios"] + " " +
    features_df["demographics"] + " " +
    features_df["type"] + " " +
    features_df["synopsis"]
)

# %%
features_df[
    ["title", "combined_features"]
].head()
# Out:
#                              title  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                                                                                                                                                                          combined_features
# 0  action__award_winning__sci-fi adult_cast__space sunrise unknown tv crime is timeless. by the year 2071, humanity has expanded across the galaxy, filling the surface of other planets with settlemen...
# 1  action__sci-fi adult_cast__space bones unknown movie another day, another bounty—such is the life of the often unlucky crew of the bebop. however, this routine is interrupted when faye, who is cha...
# 2  action__adventure__sci-fi adult_cast madhouse shounen tv vash the stampede is the man with a $$60,000,000,000 bounty on his head. the reason: he's a merciless villain who lays waste to all those t...
# 3  action__drama__mystery__supernatural detective sunrise unknown tv though hidden away from the general public, witches—those with supernatural powers—have always existed in human societies. neither...
# 4  action__adventure__fantasy unknown toei_animation shounen tv it is the dark century and the people are suffering under the rule of the devil, vandel, who is able to manipulate monsters. the vandel...

# %%
recommendation_df = features_df[
    [
        "mal_id",
        "title",
        "combined_features",
        "url"
    ]
].copy()

# %%
recommendation_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28491 entries, 0 to 28490
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mal_id             28491 non-null  int64
#  1   title              28491 non-null  str
#  2   combined_features  28491 non-null  str
#  3   url                28491 non-null  str
# dtypes: int64(1), str(3)
# memory usage: 13.0 MB

# %%
recommendation_df.to_csv(
    "../data/processed/anime_recommendation_features.csv",
    index=False
)
